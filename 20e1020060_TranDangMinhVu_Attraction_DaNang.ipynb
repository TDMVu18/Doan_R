# %%
import random
import pandas as pd
from time import sleep
import csv
import numpy as np
import datetime 
from datetime import date
from datetime import datetime
import matplotlib 
import matplotlib.pyplot as plt

# %% [markdown]
# get dâtframe

# %%
place_df = pd.read_csv('./Place.csv')
rv1 = pd.read_csv('./Review1.csv')
rv2 = pd.read_csv('./Review2.csv')
rv3 = pd.read_csv('./Review3.csv')
rv4 = pd.read_csv('./Review4.csv')
rv5 = pd.read_csv('./Review5.csv')
review_df = pd.concat([rv1, rv2, rv3, rv4, rv5])
review_df
# Out:
# C:\Users\Administrator\AppData\Local\Programs\Python\Python39\lib\site-packages\IPython\core\interactiveshell.py:3457: DtypeWarning: Columns (12) have mixed types.Specify dtype option on import or set low_memory=False.
#   exec(code_obj, self.user_global_ns, self.user_ns)
#         Reviewer's name           Reviewer's id     Reviewer's address  \
# 0              Jae Park    /Profile/jaeyoung815     Không có thông tin
# 1            Elsinore A       /Profile/FE123456                  Texas
# 2              Phoebe L     /Profile/phoebel512  Hồng Kông, Trung Quốc
# 3               SSSrita        /Profile/SSSrita     Không có thông tin
# 4              Kobokaeh       /Profile/Kobokaeh       Sepang, Malaysia
# ...                 ...                     ...                    ...
# 66277     Sonnguyen7791  /Profile/Sonnguyen7791     Không có thông tin
# 66278           Linhanh    /Profile/Linhanh7791     Không có thông tin
# ...

# %%
place_df
# Out:
#                          Place's name  \
# 0     Bảo Tàng Chứng Tích Chiến Tranh
# 1          Bưu điện trung tâm Sài Gòn
# 2               Văn Miếu Quốc Tử Giám
# 3                    Núi Ngũ Hành Sơn
# 4                    Bãi Biển An Bằng
# ...                               ...
# 6067                     Happy Riders
# 6068  Bảo tàng nước mắm Làng Chài Xưa
# 6069        Trampoline Club "Impulse"
# 6070               Kite & Surf School
# 6071      Shop Hoa Chu Choa Phan Rang
#
#                                            Place's rank  \
# 0     Số 2 trong 244 hoạt động giải trí tại Thành ph...
# 1     Số 3 trong 244 hoạt động giải trí tại Thành ph...
# 2          Số 6 trong 259 hoạt động giải trí tại Hà Nội
# 3        Số 7 trong 88 hoạt động giải trí tại Đà Nẵng
# 4         Số 10 trong 107 hoạt động giải trí tại Hội An
# ...                                                 ...
# 6067      Số 25 trên 44 Hoạt động ngoài trời ở Mũi Né
# ...

# %%
DaNang = place_df.loc[place_df['Province'] == 'Đà Nẵng']
DaNang
# Out:
#                           Place's name  \
# 3                     Núi Ngũ Hành Sơn
# 10                        My Khe Beach
# 38                          Han Market
# 42                  Maison Spa Đà Nẵng
# 61    3D Museum Art in Paradise Danang
# ...                                ...
# 5965                          Bông Spa
# 5966                       Coffee Farm
# 5967                        Sky 21 Bar
# 5968                  Organic Plus Spa
# 5987                   Hồ Xanh Đà Nẵng
#
#                                            Place's rank  \
# 3        Số 7 trong 88 hoạt động giải trí tại Đà Nẵng
# 10       Số 9 trong 88 hoạt động giải trí tại Đà Nẵng
# 38                  Số 24 trên 112 Mua sắm ở Đà Nẵng
# 42             Số 1 trên 268 Spa & Sức khỏe ở Đà Nẵng
# 61       Số 1 trong 88 hoạt động giải trí tại Đà Nẵng
# ...                                                 ...
# 5965  Số 3 trên 3 Vui chơi & Giải trí ở Son Tra Peni...
# ...

# %%
a = "12 tháng 9, năm 2022"
a = a.replace(",", "/")
a = a.replace(" ", "")
a = a.replace("tháng", "/")
a = a.replace("năm", "")
print(a) 
dt = datetime.strptime(a,'%d/%m/%Y')
print(dt)
# Out:
# 12/9/2022
# 2022-09-12 00:00:00

# %% [markdown]
# % Null

# %%
a =[]
for col in DaNang.columns:
    a.append(col)
a
for i in range(0,len(a)):
    clname = a[i]
    Null = DaNang[clname].isnull().sum()
    print("%Null cua cot", clname, "la:", Null/len(DaNang)*100 ,"%")
# Out:
# %Null cua cot Place's name la: 0.0 %
# %Null cua cot Place's rank la: 0.0 %
# %Null cua cot Place's type la: 0.3305785123966942 %
# %Null cua cot Place's status la: 43.80165289256198 %
# %Null cua cot Place's time la: 43.80165289256198 %
# %Null cua cot Place's images la: 0.0 %
# %Null cua cot Place's url la: 0.0 %
# %Null cua cot Place's rate la: 21.983471074380166 %
# %Null cua cot Place's total reviewer la: 0.0 %
# %Null cua cot Place's 5 points la: 0.0 %
# %Null cua cot Place's 4 points la: 0.0 %
# %Null cua cot Place's 3 points la: 0.0 %
# %Null cua cot Place's 2 points la: 0.0 %
# %Null cua cot Place's 1 points la: 0.0 %
# %Null cua cot retrived_date la: 0.0 %
# %Null cua cot Province la: 0.0 %

# %% [markdown]
# Các giá trị trung bình

# %%
#Phân tích các trường dữ liệu cố định
print(DaNang.describe())
image_string = DaNang["Place's images"]
print(image_string.describe())
# Out:
#        Place's total reviewer  Place's 5 points  Place's 4 points  \
# count              605.000000        605.000000        605.000000
# mean                92.636364         53.542149         24.033058
# std                525.425230        258.196419        177.461969
# min                  0.000000          0.000000          0.000000
# 25%                  1.000000          0.000000          0.000000
# 50%                  5.000000          3.000000          0.000000
# 75%                 23.000000         15.000000          2.000000
# max               7774.000000       3517.000000       2937.000000
#
#        Place's 3 points  Place's 2 points  Place's 1 points
# count        605.000000        605.000000        605.000000
# mean          10.535537          2.479339          2.049587
# std           75.675113         17.245356         11.994377
# min            0.000000          0.000000          0.000000
# 25%            0.000000          0.000000          0.000000
# ...

# %% [markdown]
# Biểu đồ tần suất dữ liệu số

# %%
plt.hist(image_string)
plt.title("Place's images Histogram")
plt.xlabel("Value")
plt.ylabel("Frequency")
plt.show()

# %%
plt.hist(DaNang["Place's total reviewer"])
plt.title("Place's total reviewer Histogram")
plt.xlabel("Value")
plt.ylabel("Frequency")
plt.show()

# %%
plt.hist(DaNang["Place's 5 points"])
plt.title("Place's 5 points Histogram")
plt.xlabel("Value")
plt.ylabel("Frequency")
plt.show()

# %%
plt.hist(DaNang["Place's 4 points"], 30)
plt.title("Place's 4 points Histogram")
plt.xlabel("Value")
plt.ylabel("Frequency")
plt.show()

# %%
plt.hist(DaNang["Place's 3 points"], 10)
plt.title("Place's 3 points Histogram")
plt.xlabel("Value")
plt.ylabel("Frequency")
plt.show()

# %%
plt.hist(DaNang["Place's 2 points"], 20)
plt.title("Place's 2 points Histogram")
plt.xlabel("Value")
plt.ylabel("Frequency")
plt.show()

# %%
plt.hist(DaNang["Place's 1 points"], 30)
plt.title("Place's 1 points Histogram")
plt.xlabel("Value")
plt.ylabel("Frequency")
plt.show()
